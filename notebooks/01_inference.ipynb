# %%
# 🚀 Install required packages for running the model
# - transformers: for loading and running LLMs
# - datasets: optional, for dataset handling
# - peft: for later LoRA experiments
# - accelerate: for optimized GPU usage in Colab
# !pip install -q transformers datasets peft accelerate

# %%
# 🔍 Check GPU availability in Colab
import torch
if torch.cuda.is_available():
    print("GPU is available:", torch.cuda.get_device_name(0))
else:
    print("GPU not available. Make sure Runtime -> Change runtime type -> GPU is selected")
# Out:
# GPU is available: Tesla T4

# %%
# 🔍 Check GPU properties and memory in Colab
if torch.cuda.is_available():
    device = torch.cuda.current_device()
    print(f"✅ GPU is available: {torch.cuda.get_device_name(device)}")
    print(f"  - CUDA version: {torch.version.cuda}")
    print(f"  - PyTorch version: {torch.__version__}")

    # GPU memory stats
    total_mem = torch.cuda.get_device_properties(device).total_memory / 1e9
    reserved_mem = torch.cuda.memory_reserved(device) / 1e9
    allocated_mem = torch.cuda.memory_allocated(device) / 1e9
    free_mem = reserved_mem - allocated_mem

    print(f"  - Total memory: {total_mem:.2f} GB")
    print(f"  - Reserved memory: {reserved_mem:.2f} GB")
    print(f"  - Allocated memory: {allocated_mem:.2f} GB")
    print(f"  - Free memory in reserved pool: {free_mem:.2f} GB")
else:
    print("❌ GPU not available. Make sure Runtime -> Change runtime type -> GPU is selected")
# Out:
# ✅ GPU is available: Tesla T4
#   - CUDA version: 12.8
#   - PyTorch version: 2.10.0+cu128
#   - Total memory: 15.64 GB
#   - Reserved memory: 0.00 GB
#   - Allocated memory: 0.00 GB
#   - Free memory in reserved pool: 0.00 GB

# %%
# 📦 Import libraries
from transformers import AutoModelForCausalLM, AutoTokenizer

MODEL_ID = "Qwen/Qwen2-0.5B" # Change to your model ID if needed  "Qwen/Qwen2-7B-Instruct", "Qwen/Qwen2-0.5B"  "Qwen/Qwen2-0.5B"
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# %%
# ==============================
# 🔹 Load tokenizer
# ==============================
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token  # Ensure padding token is set

# ==============================
# 🔹 Load model
# ==============================
model = AutoModelForCausalLM.from_pretrained(
    MODEL_ID,
    torch_dtype=torch.bfloat16 if DEVICE=="cuda" else torch.float32,
    device_map="auto" if DEVICE=="cuda" else None,
    trust_remote_code=True
)

# Set model to evaluation mode
model.eval()

print(f"Model {MODEL_ID} loaded on {DEVICE} ✅")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/661 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors:   0%|          | 0.00/988M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/290 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/138 [00:00<?, ?B/s]
# Model Qwen/Qwen2-0.5B loaded on cuda ✅

# %%
# ==============================
# 🔹 Inference helper function
# ==============================
def generate_text(prompt, max_length=128, temperature=0.7):
    """
    Generates text from a given prompt using the loaded model.
    """
    inputs = tokenizer(prompt, return_tensors="pt").to(DEVICE)
    outputs = model.generate(
        **inputs,
        max_new_tokens=max_length,
        temperature=temperature,
        do_sample=True
    )
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# %%
# Example usage
sample_prompt = "Explain in simple terms how a transformers work."  # "Explain in simple terms how a DL transformers model work."
print(generate_text(sample_prompt))
# Out:
# Setting `pad_token_id` to `eos_token_id`:151643 for open-end generation.
# Explain in simple terms how a transformers work. A transformer is a device that uses voltage and magnetic fields to produce alternating current. When a voltage is applied to a transformer, the magnetic field and electric field are generated within it. The voltage is then used to move an electric current through a long wire, which is then used to move an electric current through a second long wire, which is then used to move an electric current through a third long wire, and so on, until the final long wire is used to move an electric current through a final long wire, which is then used to move electric current through a final long wire, and so on, until the entire circuit is complete.

# %% [markdown]
# # 🔹 Transformer Architecture Overview
#
# A Transformer processes text in the following general flow:
#
# 1. **Tokenization:** Text is split into tokens (subwords) and mapped to integer IDs.
# 2. **Embeddings:** Each token ID is converted into a high-dimensional embedding vector.
# 3. **Positional Encoding:** Adds information about token positions in the sequence.
# 4. **Encoder / Decoder Layers:** Composed of multi-head self-attention and feed-forward layers.
# 5. **Output Projection:** Produces logits for each token in the vocabulary.
# 6. **Softmax & Generation:** Converts logits into probabilities to predict the next token.
#
# ---
#
# <img src="./images/transformer_flow_v1.png"
#      alt="Simplified Transformer Flow"
#      width="600"/>

# %%
# ==============================
# 🔹 Access tokenizer vocabulary
# ==============================
vocab = tokenizer.get_vocab()  # Dictionary: token -> ID
print(f"Vocabulary size: {len(vocab)} tokens")
# Out:
# Vocabulary size: 151646 tokens

# %%
import random

def sample_vocab(tokenizer, N=10):
    """
    Randomly select N items from the tokenizer's vocabulary and print them.
    """
    vocab = tokenizer.get_vocab()  # token -> ID
    sample_tokens = random.sample(list(vocab.items()), N)

    print(f"Randomly selected {N} vocabulary tokens and their IDs:\n")
    for token, token_id in sample_tokens:
        print(f"{token_id:>5} → {token}")

# Example: show 15 random tokens
sample_vocab(tokenizer, N=100)
# Out:
# Randomly selected 100 vocabulary tokens and their IDs:
#
# 61676 → Ð»ÐµÐ½Ð¸Ñı
# 74724 → ĠAlternate
# 41068 → Ġdib
# 34833 → itÃ©s
# 48604 → Ġlongitud
# 62076 → Directive
# 104175 → åıįåºĶ
# 33657 → Ġmines
# 77538 → .Acc
#  3812 → Position
# 57765 → .vert
# 16829 → Ġdifficulty
# 69703 → ĉView
# 76373 → ĉtd
# 55053 → Ġjuicy
# 35663 → /vendor
# 29868 → Ġdaughters
# 117181 → è¢«åĪ¤
# 79247 → ĠFir
# 147918 → ðŁĮ¤
# 44321 → Ġenforced
# 96333 → ĠAppliances
# 112855 → çªľ
# 110601 → åĲĮçŃī
# 59957 → gx
# 141516 → ãĤĴä½ľãģ£ãģ¦
# 140338 → ĠÐ·Ð°Ð±Ð¾Ð»ÐµÐ²Ð°Ð½Ð¸Ñı
# 36276 → PDO
# 31328 → ìĿ¸
# 10779 → Ġplants
# 44913 → ĠOUR
#  5510 → Ġways
# 57521 → .logo
# 51826 → yx
# 68477 → ĠCarb
# 110817 → æī¾ä¸ª
# 74045 → :The
# 94499 → ToListAsync
# 68372 → ĠEph
# 25772 → Æ°á»
# 96739 → Ġdomicile
# 114404 → è¾¹ä¸Ĭ
# 145643 → ìŁĪ
# 108253 → åħ¼èģĮ
# 87676 → Ġ")"Ċ
# 146001 → ËĤ
# 16191 → Ġswim
# 29016 → Ġtechnological
# 123810 → ï»
# 143105 → à¸Ľà¸±à¸Īà¸Īà¸±à¸¢
# 43597 → _coll
# 83110 → cac
# 147364 → áµĪ
# 124215 → ãģ¨æĢĿ
# 149019 → âĢµ
# 110244 → å¤§æ¦Ĥæĺ¯
# 73083 → Ġinterstate
# 72639 → Ġdissolve
# 25377 → Ġappearing
# 24555 → Arial
# 20736 → adians
# 54659 → PMENT
# 17513 → ĠAlbert
# 151507 → ðĿļģ
# 78908 → Ġindifferent
# 84611 → -League
# 39120 → Mu
# 114398 → éĹľéįµ
# 123547 → ðª©
# 18571 → _gshared
# 86099 → Ġcrossings
# 115213 → çĲĨæĥ³ä¿¡å¿µ
#  4060 → see
# 122246 → æ±Ń
# 66178 → weetalert
# 25234 → .addAttribute
# 104872 → æĭħå½ĵ
#  9076 → Ġwx
# 126569 → ×©×ķ×ĺ
# 139866 → ×ŀ×¤×Ļ
# 108298 → æ¼ıæ´ŀ
# 51058 → rename
# 137432 → Ð¶Ð¸ÑĤÑĮ
# 77322 → ĠgÃ©n
# 52887 → ë£
# 116152 → ä¾ĽåĽ¾
# 82574 → .linkLabel
# 131109 → à¸Ĺà¸¸à¸ģà¸Ħà¸Ļ
# 143279 → ìĸ¼
# 139135 → ×ª×Ļ×Ĳ×ķ×¨
# 72249 → ĠDamon
# 38793 → .getRequest
# 128451 → Ġcáº§u
# 126911 → à¸ķà¸Ńà¸ļ
# 23552 → Ġoxygen
#  7609 → [-
# 120372 → è¶¿
# 131300 → sanÄ±z
# 115741 → ä¸Ńå¿ĥåŁİåĮº
#  6474 → ondon

# %%
import random

def sample_vocab_by_language(tokenizer, N=10, language="en"):
    """
    🔹 Randomly select N tokens from the tokenizer vocabulary filtered by language.

    Parameters:
    - tokenizer: the HuggingFace tokenizer object
    - N: number of tokens to sample
    - language: target language, e.g., "en" for English, "fr" for French, "es" for Spanish

    Note:
    - Tokenizers often use subwords (BPE / SentencePiece), so tokens may not be full words.
    - This function approximates language filtering by checking character codes.
    """

    # 1️⃣ Get the full vocabulary: a dictionary {token_string: token_id}
    vocab = tokenizer.get_vocab()

    # 2️⃣ Filter tokens based on language
    if language == "en":
        # Keep only ASCII characters → mostly English tokens/subwords
        filtered_tokens = [
            item for item in vocab.items()
            if all(ord(c) < 128 for c in item[0])
        ]
    elif language == "fr" or language == "es":
        # Keep tokens containing non-ASCII characters → likely accented letters
        filtered_tokens = [
            item for item in vocab.items()
            if any(ord(c) > 127 for c in item[0])
        ]
    else:
        # No filtering, keep all tokens
        filtered_tokens = list(vocab.items())

    # 3️⃣ Randomly select N tokens from the filtered list
    # If filtered list is smaller than N, take all tokens
    sample_tokens = random.sample(filtered_tokens, min(N, len(filtered_tokens)))

    # 4️⃣ Print the results in a student-friendly way
    print(f"Randomly selected {len(sample_tokens)} '{language}' vocabulary tokens:\n")
    for token, token_id in sample_tokens:
        print(f"{token_id:>5} → {token}")

# %%
# ==============================
# 🔹 Example Usage for Students
# ==============================
# Show 10 English tokens
sample_vocab_by_language(tokenizer, N=5, language="en")

# Show 5 French tokens
sample_vocab_by_language(tokenizer, N=5, language="fr")

# %%
import re

def print_model_modules_forward_table(model, sample_input=None):
    """
    Prints modules in forward execution order in a table.
    Shows weight shapes, trainable status, output shape, and detailed objective.
    """

    device = next(model.parameters()).device
    if sample_input is not None:
        sample_input = sample_input.to(device)

    module_outputs = {}
    execution_order = []

    # Hook to record forward execution order and outputs
    def hook_fn(name):
        def hook(module, input, output):
            if name not in execution_order:
                execution_order.append(name)
            module_outputs[name] = tuple(output.shape) if isinstance(output, torch.Tensor) else str(type(output))
        return hook

    hooks = []
    for name, module in model.named_modules():
        if len(list(module.children())) == 0:  # leaf modules only
            hooks.append(module.register_forward_hook(hook_fn(name)))

    if sample_input is not None:
        model.eval()
        with torch.no_grad():
            _ = model(sample_input)

    for h in hooks:
        h.remove()

    # Table header
    header = f"{'Module Name':<40} | {'Weight Shapes':<25} | {'Status':<15} | {'Output':<15} | Comment"
    print("\n" + "-"*170)
    print(header)
    print("-"*170)

    block_pattern = re.compile(r"layers\.(\d+)\.")
    previous_block = None

    for name in execution_order:
        module = dict(model.named_modules())[name]
        params = list(module.parameters())
        param_shapes = [tuple(p.shape) for p in params] if params else "No params"
        status = "Trainable" if any(p.requires_grad for p in params) else "Non-trainable"
        output_shape = module_outputs.get(name, "N/A")

        # Detailed objective comments
        comment = ""
        lname = name.lower()
        if "embed" in lname:
            comment = "Token embedding: maps token IDs into vectors."
        elif "rotary" in lname:
            comment = "Rotary embeddings: encode token positions."
        elif "attn" in lname or "attention" in lname:
            comment = "Self-attention: gather info from all tokens."
        elif "q_proj" in lname:
            comment = "Query projection for attention."
        elif "k_proj" in lname:
            comment = "Key projection for attention."
        elif "v_proj" in lname:
            comment = "Value projection weighted by attention."
        elif "o_proj" in lname:
            comment = "Attention output projection."
        elif "mlp" in lname:
            comment = "Feed-forward network."
        elif "up_proj" in lname:
            comment = "MLP expansion: increase hidden dimension."
        elif "down_proj" in lname:
            comment = "MLP compression: reduce hidden dimension."
        elif "gate" in lname:
            comment = "Gating mechanism to modulate flow."
        elif "norm" in lname:
            comment = "LayerNorm: stabilize hidden states."
        elif "lm_head" in lname or "head" in lname:
            comment = "Final projection to vocabulary logits."
        elif "linear" in module.__class__.__name__.lower():
            comment = "Linear: weighted sum + bias."
        elif "act_fn" in lname:
            comment = "Nonlinear activation function."

        # Optional vertical spacing between blocks
        match = block_pattern.search(name)
        block_idx = int(match.group(1)) if match else None
        is_block = block_idx is not None
        if (is_block and previous_block is not None and block_idx != previous_block) or \
           (not is_block and previous_block is not None):
            print("")

        previous_block = block_idx if is_block else None

        # Table row
        print(f"{name:<40} | {str(param_shapes):<25} | {status:<15} | {str(output_shape):<15} | {comment}")
        if "embed" in lname or "rotary" in lname :
          print("")

    print("-"*170)

# %% [markdown]
# # 🔹 How a weight matrix multiplies the input
#
# <img src="./images/multi.png"
#      alt="Simplified Transformer Flow"
#      width="600"/>
#
# # It is standard matrix multiplication

# %%
sample_input = torch.randint(0, tokenizer.vocab_size, (1, 16), dtype=torch.long)
print(sample_input.shape)
print(sample_input)

# Print layers + output shapes (automatically moves input to model device)
print_model_modules_forward_table(model, sample_input)
# Out:
# torch.Size([1, 16])
# tensor([[ 52528,  76778, 106167,  50605,  11687,  72824,  40097, 133533,  46614,
#          113946, 147902,  36746,  51602,   4250,  32075, 134196]])
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Module Name                              | Weight Shapes             | Status          | Output          | Comment
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# model.embed_tokens                       | [(151936, 896)]           | Trainable       | (1, 16, 896)    | Token embedding: maps token IDs into vectors.
#
# model.rotary_emb                         | No params                 | Non-trainable   | <class 'tuple'> | Rotary embeddings: encode token positions.
#
# model.layers.0.input_layernorm           | [(896,)]                  | Trainable       | (1, 16, 896)    | LayerNorm: stabilize hidden states.
# model.layers.0.self_attn.q_proj          | [(896, 896), (896,)]      | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.0.self_attn.k_proj          | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.0.self_attn.v_proj          | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.0.self_attn.o_proj          | [(896, 896)]              | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.0.post_attention_layernorm  | [(896,)]                  | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.0.mlp.gate_proj             | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.0.mlp.act_fn                | No params                 | Non-trainable   | (1, 16, 4864)   | Feed-forward network.
# model.layers.0.mlp.up_proj               | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.0.mlp.down_proj             | [(896, 4864)]             | Trainable       | (1, 16, 896)    | Feed-forward network.
#
# model.layers.1.input_layernorm           | [(896,)]                  | Trainable       | (1, 16, 896)    | LayerNorm: stabilize hidden states.
# model.layers.1.self_attn.q_proj          | [(896, 896), (896,)]      | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.1.self_attn.k_proj          | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.1.self_attn.v_proj          | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.1.self_attn.o_proj          | [(896, 896)]              | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.1.post_attention_layernorm  | [(896,)]                  | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.1.mlp.gate_proj             | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.1.mlp.act_fn                | No params                 | Non-trainable   | (1, 16, 4864)   | Feed-forward network.
# model.layers.1.mlp.up_proj               | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.1.mlp.down_proj             | [(896, 4864)]             | Trainable       | (1, 16, 896)    | Feed-forward network.
#
# model.layers.2.input_layernorm           | [(896,)]                  | Trainable       | (1, 16, 896)    | LayerNorm: stabilize hidden states.
# model.layers.2.self_attn.q_proj          | [(896, 896), (896,)]      | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.2.self_attn.k_proj          | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.2.self_attn.v_proj          | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.2.self_attn.o_proj          | [(896, 896)]              | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.2.post_attention_layernorm  | [(896,)]                  | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.2.mlp.gate_proj             | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.2.mlp.act_fn                | No params                 | Non-trainable   | (1, 16, 4864)   | Feed-forward network.
# model.layers.2.mlp.up_proj               | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.2.mlp.down_proj             | [(896, 4864)]             | Trainable       | (1, 16, 896)    | Feed-forward network.
#
# model.layers.3.input_layernorm           | [(896,)]                  | Trainable       | (1, 16, 896)    | LayerNorm: stabilize hidden states.
# model.layers.3.self_attn.q_proj          | [(896, 896), (896,)]      | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.3.self_attn.k_proj          | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.3.self_attn.v_proj          | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.3.self_attn.o_proj          | [(896, 896)]              | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.3.post_attention_layernorm  | [(896,)]                  | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.3.mlp.gate_proj             | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.3.mlp.act_fn                | No params                 | Non-trainable   | (1, 16, 4864)   | Feed-forward network.
# model.layers.3.mlp.up_proj               | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.3.mlp.down_proj             | [(896, 4864)]             | Trainable       | (1, 16, 896)    | Feed-forward network.
#
# model.layers.4.input_layernorm           | [(896,)]                  | Trainable       | (1, 16, 896)    | LayerNorm: stabilize hidden states.
# model.layers.4.self_attn.q_proj          | [(896, 896), (896,)]      | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.4.self_attn.k_proj          | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.4.self_attn.v_proj          | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.4.self_attn.o_proj          | [(896, 896)]              | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.4.post_attention_layernorm  | [(896,)]                  | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.4.mlp.gate_proj             | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.4.mlp.act_fn                | No params                 | Non-trainable   | (1, 16, 4864)   | Feed-forward network.
# model.layers.4.mlp.up_proj               | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.4.mlp.down_proj             | [(896, 4864)]             | Trainable       | (1, 16, 896)    | Feed-forward network.
#
# model.layers.5.input_layernorm           | [(896,)]                  | Trainable       | (1, 16, 896)    | LayerNorm: stabilize hidden states.
# model.layers.5.self_attn.q_proj          | [(896, 896), (896,)]      | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.5.self_attn.k_proj          | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.5.self_attn.v_proj          | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.5.self_attn.o_proj          | [(896, 896)]              | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.5.post_attention_layernorm  | [(896,)]                  | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.5.mlp.gate_proj             | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.5.mlp.act_fn                | No params                 | Non-trainable   | (1, 16, 4864)   | Feed-forward network.
# model.layers.5.mlp.up_proj               | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.5.mlp.down_proj             | [(896, 4864)]             | Trainable       | (1, 16, 896)    | Feed-forward network.
#
# model.layers.6.input_layernorm           | [(896,)]                  | Trainable       | (1, 16, 896)    | LayerNorm: stabilize hidden states.
# model.layers.6.self_attn.q_proj          | [(896, 896), (896,)]      | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.6.self_attn.k_proj          | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.6.self_attn.v_proj          | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.6.self_attn.o_proj          | [(896, 896)]              | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.6.post_attention_layernorm  | [(896,)]                  | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.6.mlp.gate_proj             | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.6.mlp.act_fn                | No params                 | Non-trainable   | (1, 16, 4864)   | Feed-forward network.
# model.layers.6.mlp.up_proj               | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.6.mlp.down_proj             | [(896, 4864)]             | Trainable       | (1, 16, 896)    | Feed-forward network.
#
# model.layers.7.input_layernorm           | [(896,)]                  | Trainable       | (1, 16, 896)    | LayerNorm: stabilize hidden states.
# model.layers.7.self_attn.q_proj          | [(896, 896), (896,)]      | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.7.self_attn.k_proj          | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.7.self_attn.v_proj          | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.7.self_attn.o_proj          | [(896, 896)]              | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.7.post_attention_layernorm  | [(896,)]                  | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.7.mlp.gate_proj             | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.7.mlp.act_fn                | No params                 | Non-trainable   | (1, 16, 4864)   | Feed-forward network.
# model.layers.7.mlp.up_proj               | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.7.mlp.down_proj             | [(896, 4864)]             | Trainable       | (1, 16, 896)    | Feed-forward network.
#
# model.layers.8.input_layernorm           | [(896,)]                  | Trainable       | (1, 16, 896)    | LayerNorm: stabilize hidden states.
# model.layers.8.self_attn.q_proj          | [(896, 896), (896,)]      | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.8.self_attn.k_proj          | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.8.self_attn.v_proj          | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.8.self_attn.o_proj          | [(896, 896)]              | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.8.post_attention_layernorm  | [(896,)]                  | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.8.mlp.gate_proj             | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.8.mlp.act_fn                | No params                 | Non-trainable   | (1, 16, 4864)   | Feed-forward network.
# model.layers.8.mlp.up_proj               | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.8.mlp.down_proj             | [(896, 4864)]             | Trainable       | (1, 16, 896)    | Feed-forward network.
#
# model.layers.9.input_layernorm           | [(896,)]                  | Trainable       | (1, 16, 896)    | LayerNorm: stabilize hidden states.
# model.layers.9.self_attn.q_proj          | [(896, 896), (896,)]      | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.9.self_attn.k_proj          | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.9.self_attn.v_proj          | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.9.self_attn.o_proj          | [(896, 896)]              | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.9.post_attention_layernorm  | [(896,)]                  | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.9.mlp.gate_proj             | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.9.mlp.act_fn                | No params                 | Non-trainable   | (1, 16, 4864)   | Feed-forward network.
# model.layers.9.mlp.up_proj               | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.9.mlp.down_proj             | [(896, 4864)]             | Trainable       | (1, 16, 896)    | Feed-forward network.
#
# model.layers.10.input_layernorm          | [(896,)]                  | Trainable       | (1, 16, 896)    | LayerNorm: stabilize hidden states.
# model.layers.10.self_attn.q_proj         | [(896, 896), (896,)]      | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.10.self_attn.k_proj         | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.10.self_attn.v_proj         | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.10.self_attn.o_proj         | [(896, 896)]              | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.10.post_attention_layernorm | [(896,)]                  | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.10.mlp.gate_proj            | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.10.mlp.act_fn               | No params                 | Non-trainable   | (1, 16, 4864)   | Feed-forward network.
# model.layers.10.mlp.up_proj              | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.10.mlp.down_proj            | [(896, 4864)]             | Trainable       | (1, 16, 896)    | Feed-forward network.
#
# model.layers.11.input_layernorm          | [(896,)]                  | Trainable       | (1, 16, 896)    | LayerNorm: stabilize hidden states.
# model.layers.11.self_attn.q_proj         | [(896, 896), (896,)]      | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.11.self_attn.k_proj         | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.11.self_attn.v_proj         | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.11.self_attn.o_proj         | [(896, 896)]              | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.11.post_attention_layernorm | [(896,)]                  | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.11.mlp.gate_proj            | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.11.mlp.act_fn               | No params                 | Non-trainable   | (1, 16, 4864)   | Feed-forward network.
# model.layers.11.mlp.up_proj              | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.11.mlp.down_proj            | [(896, 4864)]             | Trainable       | (1, 16, 896)    | Feed-forward network.
#
# model.layers.12.input_layernorm          | [(896,)]                  | Trainable       | (1, 16, 896)    | LayerNorm: stabilize hidden states.
# model.layers.12.self_attn.q_proj         | [(896, 896), (896,)]      | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.12.self_attn.k_proj         | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.12.self_attn.v_proj         | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.12.self_attn.o_proj         | [(896, 896)]              | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.12.post_attention_layernorm | [(896,)]                  | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.12.mlp.gate_proj            | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.12.mlp.act_fn               | No params                 | Non-trainable   | (1, 16, 4864)   | Feed-forward network.
# model.layers.12.mlp.up_proj              | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.12.mlp.down_proj            | [(896, 4864)]             | Trainable       | (1, 16, 896)    | Feed-forward network.
#
# model.layers.13.input_layernorm          | [(896,)]                  | Trainable       | (1, 16, 896)    | LayerNorm: stabilize hidden states.
# model.layers.13.self_attn.q_proj         | [(896, 896), (896,)]      | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.13.self_attn.k_proj         | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.13.self_attn.v_proj         | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.13.self_attn.o_proj         | [(896, 896)]              | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.13.post_attention_layernorm | [(896,)]                  | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.13.mlp.gate_proj            | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.13.mlp.act_fn               | No params                 | Non-trainable   | (1, 16, 4864)   | Feed-forward network.
# model.layers.13.mlp.up_proj              | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.13.mlp.down_proj            | [(896, 4864)]             | Trainable       | (1, 16, 896)    | Feed-forward network.
#
# model.layers.14.input_layernorm          | [(896,)]                  | Trainable       | (1, 16, 896)    | LayerNorm: stabilize hidden states.
# model.layers.14.self_attn.q_proj         | [(896, 896), (896,)]      | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.14.self_attn.k_proj         | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.14.self_attn.v_proj         | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.14.self_attn.o_proj         | [(896, 896)]              | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.14.post_attention_layernorm | [(896,)]                  | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.14.mlp.gate_proj            | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.14.mlp.act_fn               | No params                 | Non-trainable   | (1, 16, 4864)   | Feed-forward network.
# model.layers.14.mlp.up_proj              | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.14.mlp.down_proj            | [(896, 4864)]             | Trainable       | (1, 16, 896)    | Feed-forward network.
#
# model.layers.15.input_layernorm          | [(896,)]                  | Trainable       | (1, 16, 896)    | LayerNorm: stabilize hidden states.
# model.layers.15.self_attn.q_proj         | [(896, 896), (896,)]      | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.15.self_attn.k_proj         | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.15.self_attn.v_proj         | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.15.self_attn.o_proj         | [(896, 896)]              | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.15.post_attention_layernorm | [(896,)]                  | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.15.mlp.gate_proj            | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.15.mlp.act_fn               | No params                 | Non-trainable   | (1, 16, 4864)   | Feed-forward network.
# model.layers.15.mlp.up_proj              | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.15.mlp.down_proj            | [(896, 4864)]             | Trainable       | (1, 16, 896)    | Feed-forward network.
#
# model.layers.16.input_layernorm          | [(896,)]                  | Trainable       | (1, 16, 896)    | LayerNorm: stabilize hidden states.
# model.layers.16.self_attn.q_proj         | [(896, 896), (896,)]      | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.16.self_attn.k_proj         | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.16.self_attn.v_proj         | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.16.self_attn.o_proj         | [(896, 896)]              | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.16.post_attention_layernorm | [(896,)]                  | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.16.mlp.gate_proj            | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.16.mlp.act_fn               | No params                 | Non-trainable   | (1, 16, 4864)   | Feed-forward network.
# model.layers.16.mlp.up_proj              | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.16.mlp.down_proj            | [(896, 4864)]             | Trainable       | (1, 16, 896)    | Feed-forward network.
#
# model.layers.17.input_layernorm          | [(896,)]                  | Trainable       | (1, 16, 896)    | LayerNorm: stabilize hidden states.
# model.layers.17.self_attn.q_proj         | [(896, 896), (896,)]      | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.17.self_attn.k_proj         | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.17.self_attn.v_proj         | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.17.self_attn.o_proj         | [(896, 896)]              | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.17.post_attention_layernorm | [(896,)]                  | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.17.mlp.gate_proj            | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.17.mlp.act_fn               | No params                 | Non-trainable   | (1, 16, 4864)   | Feed-forward network.
# model.layers.17.mlp.up_proj              | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.17.mlp.down_proj            | [(896, 4864)]             | Trainable       | (1, 16, 896)    | Feed-forward network.
#
# model.layers.18.input_layernorm          | [(896,)]                  | Trainable       | (1, 16, 896)    | LayerNorm: stabilize hidden states.
# model.layers.18.self_attn.q_proj         | [(896, 896), (896,)]      | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.18.self_attn.k_proj         | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.18.self_attn.v_proj         | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.18.self_attn.o_proj         | [(896, 896)]              | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.18.post_attention_layernorm | [(896,)]                  | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.18.mlp.gate_proj            | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.18.mlp.act_fn               | No params                 | Non-trainable   | (1, 16, 4864)   | Feed-forward network.
# model.layers.18.mlp.up_proj              | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.18.mlp.down_proj            | [(896, 4864)]             | Trainable       | (1, 16, 896)    | Feed-forward network.
#
# model.layers.19.input_layernorm          | [(896,)]                  | Trainable       | (1, 16, 896)    | LayerNorm: stabilize hidden states.
# model.layers.19.self_attn.q_proj         | [(896, 896), (896,)]      | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.19.self_attn.k_proj         | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.19.self_attn.v_proj         | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.19.self_attn.o_proj         | [(896, 896)]              | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.19.post_attention_layernorm | [(896,)]                  | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.19.mlp.gate_proj            | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.19.mlp.act_fn               | No params                 | Non-trainable   | (1, 16, 4864)   | Feed-forward network.
# model.layers.19.mlp.up_proj              | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.19.mlp.down_proj            | [(896, 4864)]             | Trainable       | (1, 16, 896)    | Feed-forward network.
#
# model.layers.20.input_layernorm          | [(896,)]                  | Trainable       | (1, 16, 896)    | LayerNorm: stabilize hidden states.
# model.layers.20.self_attn.q_proj         | [(896, 896), (896,)]      | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.20.self_attn.k_proj         | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.20.self_attn.v_proj         | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.20.self_attn.o_proj         | [(896, 896)]              | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.20.post_attention_layernorm | [(896,)]                  | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.20.mlp.gate_proj            | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.20.mlp.act_fn               | No params                 | Non-trainable   | (1, 16, 4864)   | Feed-forward network.
# model.layers.20.mlp.up_proj              | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.20.mlp.down_proj            | [(896, 4864)]             | Trainable       | (1, 16, 896)    | Feed-forward network.
#
# model.layers.21.input_layernorm          | [(896,)]                  | Trainable       | (1, 16, 896)    | LayerNorm: stabilize hidden states.
# model.layers.21.self_attn.q_proj         | [(896, 896), (896,)]      | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.21.self_attn.k_proj         | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.21.self_attn.v_proj         | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.21.self_attn.o_proj         | [(896, 896)]              | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.21.post_attention_layernorm | [(896,)]                  | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.21.mlp.gate_proj            | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.21.mlp.act_fn               | No params                 | Non-trainable   | (1, 16, 4864)   | Feed-forward network.
# model.layers.21.mlp.up_proj              | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.21.mlp.down_proj            | [(896, 4864)]             | Trainable       | (1, 16, 896)    | Feed-forward network.
#
# model.layers.22.input_layernorm          | [(896,)]                  | Trainable       | (1, 16, 896)    | LayerNorm: stabilize hidden states.
# model.layers.22.self_attn.q_proj         | [(896, 896), (896,)]      | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.22.self_attn.k_proj         | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.22.self_attn.v_proj         | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.22.self_attn.o_proj         | [(896, 896)]              | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.22.post_attention_layernorm | [(896,)]                  | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.22.mlp.gate_proj            | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.22.mlp.act_fn               | No params                 | Non-trainable   | (1, 16, 4864)   | Feed-forward network.
# model.layers.22.mlp.up_proj              | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.22.mlp.down_proj            | [(896, 4864)]             | Trainable       | (1, 16, 896)    | Feed-forward network.
#
# model.layers.23.input_layernorm          | [(896,)]                  | Trainable       | (1, 16, 896)    | LayerNorm: stabilize hidden states.
# model.layers.23.self_attn.q_proj         | [(896, 896), (896,)]      | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.23.self_attn.k_proj         | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.23.self_attn.v_proj         | [(128, 896), (128,)]      | Trainable       | (1, 16, 128)    | Self-attention: gather info from all tokens.
# model.layers.23.self_attn.o_proj         | [(896, 896)]              | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.23.post_attention_layernorm | [(896,)]                  | Trainable       | (1, 16, 896)    | Self-attention: gather info from all tokens.
# model.layers.23.mlp.gate_proj            | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.23.mlp.act_fn               | No params                 | Non-trainable   | (1, 16, 4864)   | Feed-forward network.
# model.layers.23.mlp.up_proj              | [(4864, 896)]             | Trainable       | (1, 16, 4864)   | Feed-forward network.
# model.layers.23.mlp.down_proj            | [(896, 4864)]             | Trainable       | (1, 16, 896)    | Feed-forward network.
#
# model.norm                               | [(896,)]                  | Trainable       | (1, 16, 896)    | LayerNorm: stabilize hidden states.
# lm_head                                  | [(151936, 896)]           | Trainable       | (1, 16, 151936) | Final projection to vocabulary logits.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
import torch.nn.functional as F

def generate_text_step_by_step_table_with_logits(prompt, max_length=20, temperature=1.0, top_k=None):
    """
    Generates text token by token, printing a table-style output with probabilities and logits.
    Supports temperature=0 (greedy) and top-k sampling.
    """
    # Encode prompt
    inputs = tokenizer(prompt, return_tensors="pt")
    input_ids = inputs["input_ids"].to(DEVICE).long()

    # Check token IDs
    vocab_size = model.config.vocab_size
    if input_ids.max() >= vocab_size:
        raise ValueError(f"Token ID {input_ids.max()} exceeds vocab size {vocab_size}!")

    # Table header
    print("\n" + "-"*120)
    print(f"{'Step':<6} | {'Token ID':<8} | {'Token':<12} | {'Logit':<10} | {'Prob':<8} | {'Current Sequence'}")
    print("-"*120)

    for step in range(max_length):
        with torch.no_grad():
            outputs = model(input_ids=input_ids)
            logits = outputs.logits  # [batch, seq_len, vocab_size]

        last_logits = logits[:, -1, :]

        # Apply temperature
        if temperature > 0:
            last_logits_temp = last_logits / temperature
            # Top-k filtering
            if top_k is not None:
                values, indices = torch.topk(last_logits_temp, top_k)
                mask = torch.full_like(last_logits_temp, float('-inf'))
                mask.scatter_(1, indices, values)
                last_logits_temp = mask
            probs = F.softmax(last_logits_temp, dim=-1)
            next_token_id = torch.multinomial(probs, num_samples=1)
            logit_value = last_logits[0, next_token_id[0]].item()
        else:
            # Greedy decoding
            next_token_id = torch.argmax(last_logits, dim=-1, keepdim=True)
            probs = F.softmax(last_logits, dim=-1)
            logit_value = last_logits[0, next_token_id[0]].item()

        # Append token
        input_ids = torch.cat([input_ids, next_token_id], dim=-1)

        # Decode token and probability
        next_token_str = tokenizer.decode(next_token_id[0])
        prob_of_token = probs[0, next_token_id[0]].item()

        # Print table row
        print(f"{step+1:<6} | {next_token_id.item():<8} | {next_token_str:<12} | "
              f"{logit_value:<10.4f} | {prob_of_token:<8.4f} | {tokenizer.decode(input_ids[0])}")

    print("-"*120)
    return tokenizer.decode(input_ids[0], skip_special_tokens=True)

# %%
prompt = "Once upon a time"
generated_text = generate_text_step_by_step_table_with_logits(prompt, max_length=10, temperature=0.0, top_k=None)
print("Final generated text:\n", generated_text)
# Out:
# ------------------------------------------------------------------------------------------------------------------------
# Step   | Token ID | Token        | Logit      | Prob     | Current Sequence
# ------------------------------------------------------------------------------------------------------------------------
# 1      | 11       | ,            | 15.8750    | 0.6055   | Once upon a time,
# 2      | 1052     |  there       | 13.4375    | 0.1777   | Once upon a time, there
# 3      | 572      |  was         | 19.8750    | 0.7930   | Once upon a time, there was
# 4      | 264      |  a           | 16.2500    | 0.7852   | Once upon a time, there was a
# 5      | 883      |  man         | 12.4375    | 0.0737   | Once upon a time, there was a man
# 6      | 879      |  who         | 17.0000    | 0.3301   | Once upon a time, there was a man who
# 7      | 572      |  was         | 16.6250    | 0.1592   | Once upon a time, there was a man who was
# 8      | 1602     |  very        | 14.4375    | 0.0923   | Once upon a time, there was a man who was very
# 9      | 9080     |  rich        | 15.1250    | 0.1108   | Once upon a time, there was a man who was very rich
# 10     | 13       | .            | 19.1250    | 0.4395   | Once upon a time, there was a man who was very rich.
# ------------------------------------------------------------------------------------------------------------------------
# Final generated text:
#  Once upon a time, there was a man who was very rich.

# %%
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE


def visualize_token_embeddings_tsne(model, tokenizer, tokens, device="cpu"):
    """
    Visualizes selected token embeddings using t-SNE.

    Args:
        model: HuggingFace model
        tokenizer: corresponding tokenizer
        tokens: list of words (strings)
        device: 'cuda' or 'cpu'
    """

    model.eval()

    # -----------------------------
    # Convert tokens to token IDs
    # -----------------------------
    token_ids = []
    valid_tokens = []

    for word in tokens:
        ids = tokenizer.encode(word, add_special_tokens=False)
        if len(ids) == 1:  # only keep single-token words
            token_ids.append(ids[0])
            valid_tokens.append(word)
        else:
            print(f"Skipping '{word}' (splits into multiple tokens)")

    if len(token_ids) < 2:
        print("Not enough valid single-token words for visualization.")
        return

    # -----------------------------
    # Extract embedding layer
    # -----------------------------
    embedding_layer = model.get_input_embeddings()

    with torch.no_grad():
        embeddings = embedding_layer(torch.tensor(token_ids).to(device))

        # FIX: Convert bfloat16 → float32 before NumPy
        embeddings = embeddings.float().cpu().numpy()

    # -----------------------------
    # Apply t-SNE
    # -----------------------------
    tsne = TSNE(n_components=2, random_state=42, perplexity=min(5, len(token_ids)-1))
    embeddings_2d = tsne.fit_transform(embeddings)

    # -----------------------------
    # Plot
    # -----------------------------
    plt.figure(figsize=(10, 8))

    for i, word in enumerate(valid_tokens):
        x, y = embeddings_2d[i]
        plt.scatter(x, y)
        plt.text(x + 0.5, y + 0.5, word, fontsize=12)

    plt.title("t-SNE Visualization of Token Embeddings")
    plt.xlabel("Dimension 1")
    plt.ylabel("Dimension 2")
    plt.grid(True)
    plt.show()

# %%
tokens = [
    "king", "queen", "man", "woman",
    "dog", "cat",
    "apple", "orange",
    "bus", "motor",
    "happy", "sad"
]

visualize_token_embeddings_tsne(model, tokenizer, tokens, device=DEVICE)
